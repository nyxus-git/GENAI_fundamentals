# %%
from dotenv import load_dotenv
load_dotenv(override=True)

from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4o")

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
prompts = [
    {"role":"system", "content":"you are a javascript developer"},
    {"role":"user", "content":"difference between var, let and const in javascript"}
]
res = llm.invoke(prompts)
print(res.content)
# Out:
# In JavaScript, `var`, `let`, and `const` are keywords used to declare variables, but they have different scopes, reassignability, and hoisting behavior. Here’s a breakdown of each:
#
# ### 1. `var`
# - **Scope**: `var` is function-scoped. This means that a variable declared with `var` is accessible within the function it is declared in or globally if declared outside any function. It does not consider block scope.
# - **Hoisting**: Variables declared with `var` are hoisted to the top of their function or global context. However, they are not initialized until their assignment is executed, leading to a situation where they are `undefined` if accessed before that point.
# - **Reassignability**: You can reassign and redeclare variables declared with `var`.
#
# ```javascript
# function example() {
#   console.log(a); // undefined due to hoisting
#   var a = 5;
#   console.log(a); // 5
# }
#
# if (true) {
#   var b = 10;
# }
# console.log(b); // 10, `var` does not respect block scope
# ...

# %% [markdown]
# ##### prompts template - dynamic template

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
llm = ChatOpenAI(model="gpt-4o")
out = StrOutputParser()

# %%
#### My self chain Node

def transform_case(result:str):
    return result.upper()

# %%
prompts = ChatPromptTemplate.from_messages([
    {"role":"system", "content":"you are a translator and you will translate the text to {language}"},
    {"role":"user", "content":"{query}"}
])

# %%
# final_prompt = prompts.format_prompt(language="hinglish", query="i love python and javascript")
# res = llm.invoke(final_prompt)
# print(res.content)
# Out:
# Main Python aur JavaScript se pyaar karta hoon.

# %%
# res = llm.invoke(prompts.invoke({"language":"hindi", "query":"i love you"}).messages)
# print(res.content)
# Out:
# मैं तुमसे प्यार करता हूँ / मैं तुमसे प्यार करती हूँ (depending on the gender of the speaker)

# %%
chains
# Out:
# ChatPromptTemplate(input_variables=['language', 'query'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['language'], input_types={}, partial_variables={}, template='you are a translator and you will translate the text to {language}'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['query'], input_types={}, partial_variables={}, template='{query}'), additional_kwargs={})])
# ...

# %%
chains = prompts | llm | out | transform_case

# %%
res = chains.invoke({"language":"hinglish", "query":"i love you langchains"})
print(res)
# Out:
# MAIN TUMHE BAHUT PASAND KARTA HOON, LANGCHAINS.
