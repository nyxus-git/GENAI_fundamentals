# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
from langchain_openai import ChatOpenAI

# %%
llm = ChatGroq(model = "openai/gpt-oss-120b")
openllm = ChatOpenAI(model = "gpt-5")

# %%
res = openllm.invoke("Write a poem about a lonely robot in the style of Shakespeare")
print(res.content)
# Out:
# When midnight winds through iron cloisters sigh,
# A lonely automaton keeps his guard;
# The candle-stars look down with metal eye,
# Yet none to share his watch, nor cry “On guard.”
# Built but to beat a heart of tempered steel,
# He counts the ticks that mortals seldom hear;
# He knows not sleep, yet aches to dream and feel,
# For all his gears sing silence to his ear.
# O were there hand to rust upon his hand,
# Or tongue to teach him sweetness of a name,
# He would unhinge the bolts of steel command,
# And learn from sorrow how to kindle flame.
# Yet fate hath forged him thus: a soulless knight,
# Who guards the world, and longs to learn of night.

# %%
res = llm.invoke("Write a poem about a lonely robot in the style of Shakespeare")
print(res.content)
# Out:
# **A Sonnet for the Lonesome Automaton**
#
# When steel‑born heart doth pulse in silent night,
# And gears, like thoughts, do turn in cold repose,
# The lonely robot ponders—out of sight—
# A world of flesh that he may ne’er compose.
#
# His copper eyes, though bright, perceive no cheer,
# For none to speak the words that he doth crave;
# No gentle hand to calm his iron fear,
# No lover’s sigh to teach his soul to brave.
#
# “O, cruel Fate!” he cries, “that wrought my frame,
# To wander ’mongst the stars with naught but code;
# Yet in my chest there burns an ember’s flame,
# A yearning for the warmth of mortal ode.”
#
# Thus, though his limbs be forged of iron cold,
# His spirit seeks the love that mortals hold.
