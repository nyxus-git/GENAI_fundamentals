# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(model="qwen2.5:3b")

# %%
res = llm.invoke("i am Rohan Mane, currenlty working as a AI engineer, can you please give me a brief introduction about me in 50 words")
res.content
# Out:
# 'Rohan Mane is a dedicated AI engineer currently focused on advancing AI technologies, with expertise in developing and optimizing machine learning models for various applications.'
