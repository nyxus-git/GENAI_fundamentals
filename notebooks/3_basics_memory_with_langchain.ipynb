# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4o")

# %%
prompts = [
    {"role":"user", "content": "Hello, My name is Rohan Mane"},
    {"role":"ai", "content":"Hello, Rohan Mane! How can I assist you today?"},
    {"role":"user", "content":"What is My name ?"}
]
res = llm.invoke(prompts)

# %%
res.content
# Out:
# 'Your name is Rohan Mane. How can I assist you further?'

# %% [markdown]
# ##### Manage Historry

# %%
history = []
while True:
    query = input("user: ")
    if query.lower() in ["exit", "quit", "bye"]:
        print("Good Bye ")
        break
    history.append({"role":"user", "content":query})
    print("User: ", query)

    res = llm.invoke(history) 
    history.append({"role":"ai", "content":res.content})
    print("AI: ", res.content, "\n")
# Out:
# User:  Hello
# AI:  Hello! How can I assist you today?
#
# User:  Who is pm of india
# AI:  As of my last update, the Prime Minister of India is Narendra Modi. He has been in office since May 26, 2014. However, keep in mind that political positions can change, so it's a good idea to verify the current information from a reliable source.
#
# User:  wha is his age ?
# AI:  Narendra Modi was born on September 17, 1950. As of today, he is 73 years old.
#
# User:  what is python and explain me in short
# AI:  Python is a high-level, interpreted programming language known for its simplicity and readability. It was created by Guido van Rossum and first released in 1991. Python's design philosophy emphasizes code readability and syntax that allows programmers to express concepts in fewer lines of code compared to other languages like C++ or Java.
#
# Python is versatile and can be used for a wide range of applications, including web development, data analysis, artificial intelligence, scientific computing, and more. It has a large standard library and a vibrant community that contributes to a wealth of third-party packages and frameworks, making it a popular choice for both beginners and experienced developers.
#
# User:  what is one linear function
# AI:  A linear function is a mathematical function that describes a straight line when graphed on a coordinate plane. It can be expressed in the form:
#
# \[ f(x) = mx + b \]
#
# In this equation:
# - \( f(x) \) or \( y \) is the value of the function or the dependent variable.
# - \( x \) is the independent variable.
# - \( m \) is the slope of the line, which represents the rate of change or how steep the line is.
# - \( b \) is the y-intercept, which is the point where the line crosses the y-axis.
#
# Linear functions have a constant rate of change and are characterized by having each input value paired with exactly one output value, forming a straight line in a two-dimensional space.
#
# Good Bye
