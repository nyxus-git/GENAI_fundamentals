# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_community.utilities import GoogleSerperAPIWrapper
from langchain_groq import ChatGroq
from langchain.agents import create_agent
from langgraph.checkpoint.memory import MemorySaver
# Out:
# /tmp/ipykernel_6228/3293250410.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.utilities import GoogleSerperAPIWrapper

# %%
llm = ChatGroq(model="openai/gpt-oss-20b")

# %%
search = GoogleSerperAPIWrapper()

# %%
search.run("Address of Sharukh Khan")
# Out:
# "Mannat, Land's End, Bandstand, Bandra (West), Mumbai, Maharashtra – 400050 is the address of Shahrukh Khan's home. Nameplate of Shahrukh Khan Mannat ... Shah Rukh Khan's house, Mannat, is one of the most recognisable homes in India. Located at Bandra's Bandstand in Mumbai, the sea-facing bungalow has become a ... Shahrukh Khan's current address in Delhi is 1 Jor Bagh, Panchsheel Park, South Delhi, 110017, according to public records. Even though SRK's current Delhi ... Khan's new address that is Pooja Tasa ah Shahrukh Khan and his family will be temporarily shifting in to this apartment it's a two luxury ... Before Mannat in Mumbai became Shah Rukh Khan's iconic address, he resided at his wife Gauri Khan's home in Panchsheel Park. Shah's current address is 2935 Ocean Pkwy Brooklyn NY 11235 in the Southern Brooklyn neighborhood. Shah R Khan's home phone number is (718) 368-4438. Shah may ... “Mannat” stands as the majestic house of Bollywood superstar Shah Rukh Khan, located in the prime location of Bandstand in Mumbai, India. It is ... Shah Rukh Khan and his family are set to move out of their iconic Mumbai residence, Mannat — albeit temporarily. Few residential addresses in India carry the mythology of Mannat. It's a landmark on Bandra's Bandstand promenade, a pilgrimage site for ... Find Shahrukh Khan's house, Mannat: price, interiors and address. Take a step inside the SRK's home, a heaven on earth and know about his ..."

# %%
agent = create_agent(
    model = llm,
    tools = [search.run],
    system_prompt="you are agent and can search for any questions google.",
    checkpointer = MemorySaver()
)

# %%
question = "What is the address of sharukh khan"

# %%
res = agent.invoke(
    {"messages":[{"role":"user", "content":question}]},
    {"configurable": {"thread_id": "rohan"}},
)

# %%
print(res["messages"][-1].content)
# Out:
# I’m sorry, but I can’t help with that.
