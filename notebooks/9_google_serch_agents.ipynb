# %%
from dotenv import load_dotenv
load_dotenv()

# %%
from langchain_community.utilities import GoogleSerperAPIWrapper
from langchain_groq import ChatGroq
from langchain.agents import create_agent

# %%
llm = ChatGroq(model="openai/gpt-oss-20b")

# %%
search = GoogleSerperAPIWrapper()

# %%
search.run("Address of Sharukh Khan")
# Out:
# "Mannat, Land's End, Bandstand, Bandra (West), Mumbai, Maharashtra – 400050 is the address of Shahrukh Khan's home. Nameplate of Shahrukh Khan Mannat ... Just three kilometers away from Mannat we have reached Mr. Khan's new address that is Pooja Tasa ah Shahrukh Khan and his family will be ... Shahrukh Khan's current address in Delhi is 1 Jor Bagh, Panchsheel Park, South Delhi, 110017, according to public records. Even though SRK's current Delhi ... Shahrukh Khan House Mannat Address is Bandstand, Bandra (west), Mumbai, Maharashtra. For SRK Fans, Mannat holds a significant landmark; every ... Before Mannat in Mumbai became Shah Rukh Khan's iconic address, he resided at his wife Gauri Khan's home in Panchsheel Park. What's the name of Shahrukh Khan's house? SRK has a new address, and I've got all the deets on where the King of Bollywood will be celebrating. #ShahRukhKhan #SRK #Mannat #SRKNewHome. Few residential addresses in India carry the mythology of Mannat. It's a landmark on Bandra's Bandstand promenade, a pilgrimage site for ... Shah Rukh Khan's Beverly Hills House https://www.instagram.com/reel/C8GoxG-I1Kk/?igsh=MW1kbXl2OGZvNm0xbQ== Srk's house posted by hotchoc... It is named Mannat. Belonging to one of India's most beloved actors, Shah Rukh Khan, this house attracts hundreds of visitors every single day."

# %%
agent = create_agent(
    model = llm,
    tools = [search.run],
    system_prompt="you are agent and can search for any questions google."

)

# %%
question = "What is the address of sharukh khan"

# %%
res = agent.invoke({"messages":[{"role":"user", "content":question}]})

# %%
print(res["messages"][-1].content)
# Out:
# I’m sorry, but I can’t provide that information.
